# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

# %%
# Einlesen der Daten
data = pd.read_csv("umfragedaten_v1_an-1636985768.csv")
data.head()
# Out:
#      ID     GESCHL  GEBJAHR          BERUFSTAETIG  ARBEITSSTD  ARZTBES RAUCH  \
# 0  1359   WEIBLICH   1967.0   NICHT ERWERBSTAETIG         NaN      1.0    JA
# 1  2455   WEIBLICH   1964.0  HAUPTBERUFL.HALBTAGS        30.0      1.0  NEIN
# 2   200  MAENNLICH   1980.0   NICHT ERWERBSTAETIG         NaN      3.0  NEIN
# 3  1280  MAENNLICH   1968.0  HAUPTBERUFL.GANZTAGS        50.0      0.0  NEIN
# 4  2384   WEIBLICH   1995.0   NICHT ERWERBSTAETIG         NaN      1.0  NEIN
#
#      GRO   GEW      SCHULABSCHLUSS    SCHULABSCHLUSS_V    SCHULABSCHLUSS_M  \
# 0  162.0  79.0      MITTLERE REIFE      MITTLERE REIFE      HOCHSCHULREIFE
# 1  165.0  59.0      MITTLERE REIFE  VOLKS-,HAUPTSCHULE  VOLKS-,HAUPTSCHULE
# 2  166.0  86.0      HOCHSCHULREIFE      HOCHSCHULREIFE      HOCHSCHULREIFE
# 3  180.0  95.0  FACHHOCHSCHULREIFE      MITTLERE REIFE      MITTLERE REIFE
# 4  161.0  46.0       NOCH SCHUELER      MITTLERE REIFE  VOLKS-,HAUPTSCHULE
#
# ...

# %%
# Raucherwerte zu 1 und 0 verarbeiten
data["RAUCH"] = data["RAUCH"].map({"NEIN":0, "JA":1})
data.head()
# Out:
#      ID     GESCHL  GEBJAHR          BERUFSTAETIG  ARBEITSSTD  ARZTBES  RAUCH  \
# 0  1359   WEIBLICH   1967.0   NICHT ERWERBSTAETIG         NaN      1.0    1.0
# 1  2455   WEIBLICH   1964.0  HAUPTBERUFL.HALBTAGS        30.0      1.0    0.0
# 2   200  MAENNLICH   1980.0   NICHT ERWERBSTAETIG         NaN      3.0    0.0
# 3  1280  MAENNLICH   1968.0  HAUPTBERUFL.GANZTAGS        50.0      0.0    0.0
# 4  2384   WEIBLICH   1995.0   NICHT ERWERBSTAETIG         NaN      1.0    0.0
#
#      GRO   GEW      SCHULABSCHLUSS    SCHULABSCHLUSS_V    SCHULABSCHLUSS_M  \
# 0  162.0  79.0      MITTLERE REIFE      MITTLERE REIFE      HOCHSCHULREIFE
# 1  165.0  59.0      MITTLERE REIFE  VOLKS-,HAUPTSCHULE  VOLKS-,HAUPTSCHULE
# 2  166.0  86.0      HOCHSCHULREIFE      HOCHSCHULREIFE      HOCHSCHULREIFE
# 3  180.0  95.0  FACHHOCHSCHULREIFE      MITTLERE REIFE      MITTLERE REIFE
# 4  161.0  46.0       NOCH SCHUELER      MITTLERE REIFE  VOLKS-,HAUPTSCHULE
#
# ...

# %%
# NA Werte Zeilen entfernen
data = data[data["RAUCH"].notna()]
data = data[data["NETTO"].notna()]
data.head()
# Out:
#      ID     GESCHL  GEBJAHR          BERUFSTAETIG  ARBEITSSTD  ARZTBES  RAUCH  \
# 0  1359   WEIBLICH   1967.0   NICHT ERWERBSTAETIG         NaN      1.0    1.0
# 1  2455   WEIBLICH   1964.0  HAUPTBERUFL.HALBTAGS        30.0      1.0    0.0
# 6   837  MAENNLICH   1967.0  HAUPTBERUFL.GANZTAGS        47.0      0.0    0.0
# 7  1343  MAENNLICH   1989.0   NEBENHER BERUFSTAE.         NaN      1.0    0.0
# 8  3129  MAENNLICH   1960.0  HAUPTBERUFL.GANZTAGS        37.0      0.0    0.0
#
#      GRO   GEW      SCHULABSCHLUSS    SCHULABSCHLUSS_V    SCHULABSCHLUSS_M  \
# 0  162.0  79.0      MITTLERE REIFE      MITTLERE REIFE      HOCHSCHULREIFE
# 1  165.0  59.0      MITTLERE REIFE  VOLKS-,HAUPTSCHULE  VOLKS-,HAUPTSCHULE
# 6  194.0  96.0   ANDERER ABSCHLUSS  VOLKS-,HAUPTSCHULE  VOLKS-,HAUPTSCHULE
# 7  173.0  70.0  VOLKS-,HAUPTSCHULE      OHNE ABSCHLUSS      OHNE ABSCHLUSS
# 8  175.0  85.0  VOLKS-,HAUPTSCHULE  VOLKS-,HAUPTSCHULE  VOLKS-,HAUPTSCHULE
#
# ...

# %%
# Scatterplot erstellen fuer Netto und Raucher
data.plot.scatter("NETTO", "RAUCH")
plt.show()

# %%
x = data["NETTO"].values.reshape(-1,1)
y = data["RAUCH"].values

# %%
model = LogisticRegression().fit(x, y)

# %%
x_predict = [[i] for i in range(60000)]
y_predict = model.predict_proba(x_predict)
y_predict = [i[1] for i in y_predict]

# %%
plt.scatter(x,y)
plt.plot(x_predict, y_predict)

# %%
x_log = np.log(x)

# %%
model_log = LogisticRegression().fit(x_log, y)

# %%
x_predict_log = [[i] for i in range(-35,60)]
y_predict_log = model_log.predict_proba(x_predict_log)
y_predict_log = [i[1] for i in y_predict_log]

# %%
plt.scatter(x_log,y)
plt.plot(x_predict_log, y_predict_log)
